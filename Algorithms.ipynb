# %% [markdown]
# # Algorithms
# ref : Grokking Algorithms - An illustrated guide for programmers and other curious people, (Bhargava, n.d.)

# %% [markdown]
# ## Binary Search

# %%
def binary_search(list, item):
    low = 0
    high = len(list) - 1
    while low <= high:
        mid = (low + high)
        guess = list[mid]
        if guess == item:
            return mid
        if guess > item:
            high = mid - 1
        else:
            low = mid + 1
    return None


my_list = [1, 3, 5, 7, 9]
print (binary_search(my_list, 3)) # => 1
print (binary_search(my_list, -1)) # => None
# Out:
# 1
# None

# %% [markdown]
# ## Selection Sort

# %%
def findSmallest(arr):
    smallest = arr[0] 
    smallest_index = 0 
    for i in range(1, len(arr)):
        if arr[i] < smallest:
            smallest = arr[i]
            smallest_index = i
    return smallest_index

#Now you can use this function to write selection sort:
    
def selectionSort(arr): 
    newArr = []
    for i in range(len(arr)):
        smallest = findSmallest(arr)
        newArr.append(arr.pop(smallest))
    return newArr


print (selectionSort([5, 3, 6, 2, 10]))
# Out:
# [2, 3, 5, 6, 10]

# %% [markdown]
# ## Recursion

# %%
#bad code
def countdown(i):
    print(i)
    countdown(i-1)
#call func   
countdown(5)

# %%
#good code
def countdown(i):
    print (i)
    if i <= 0: #Base case
        return
    else: #Recursive case
        countdown(i-1)
#call func
countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# ### The Call Stack

# %%
#calls two other functions
def greet(name):
    print ("hello " + name +  " morning!")
    greet2(name)
    print ("getting ready to say bye...")
    bye()
    
#supporting functions  
def greet2(name):
    print ("how are you? "+name)
def bye():
    print ("ok bye")

#call func
greet("akshat")
# Out:
# hello akshat morning!
# how are you? akshat
# getting ready to say bye...
# ok bye

# %%
#factorial
def fact(x):
    if x == 1:
        return 1
    else:
        return x * fact(x-1)

fact(15)
# Out:
# 1307674368000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#adding by loop
def sum(arr):
    total = 0
    for x in arr:
        total += x
    return total

print (sum([1, 2, 3, 4]))
# Out:
# 10

# %%
#adding by recursion
def rec_sum(arr):
    if len(arr) == 0:
        return 0
    elif len(arr) == 1:
        return arr[0]
    else:
        return arr.pop(0) + rec_sum(arr)
    
rec_sum([1, 2, 3, 4])
# Out:
# 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#finding length of list by recursion
def rec_len(arr):
    if arr:
        return 1 + rec_len(arr[1:])
    else:
        return 0
    

rec_len([1, 2, 3, 4])
# Out:
# 4

# %%
#find max number using recursion.

def find_max(arr):
    if not arr:
        return 0
    elif len(arr) == 1:
        return arr[0]
    else:
        m = find_max(arr[1:])
        return m if m > arr[0] else arr[0]
        
find_max([1, 2, 3, 4, 5])
# Out:
# 5

# %% [markdown]
# ## Quicksort

# %%
def quicksort(array):
    if len(array) < 2:
        return array #Base case: arrays with 0 or 1 element are already “sorted.”
    else:
        pivot = array[0] #Recursive case
        less = [i for i in array[1:] if i <= pivot] #Sub-array of all the elements less than the pivot
        greater = [i for i in array[1:] if i > pivot] #Sub-array of all the elements greater than the pivot
    return quicksort(less) + [pivot] + quicksort(greater)

print (quicksort([10, 5, 2, 3]))
# Out:
# [2, 3, 5, 10]

# %% [markdown]
# ##### Quicksort vs Mergesort (why quicksort is better)
# "If you always choose a random element in the array as the
# pivot, quicksort will complete in O(n log n) time on average. Quicksort
# is one of the fastest sorting algorithms out there, and it’s a very good
# example of D&C."
